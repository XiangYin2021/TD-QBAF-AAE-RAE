# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Removal-AAE

data = {
    'Argument': ['s7', 's8', 's9', 's10', 's3', 'c1', 'c2', 's4', 's5', 's6', 'c3', 'c4', 's0', 's1', 's2', 'c0'],
    'Removal-based AAE': [0.084304029, 0.066738248, 0.066738248, 0.066738248, 0.006673061, 0.006635552, 0.00293811,
                          7.69E-05, 7.69E-05, -8.42E-06, -8.42E-06, -8.42E-06, -0.002444482, -0.002444482, -0.002444482,
                          -0.002476209]
}

# Creating DataFrame
df = pd.DataFrame(data)

# Plotting the bar chart
colors = ['skyblue' if val >= 0 else 'lightcoral' for val in df['Removal-based AAE']]
plt.figure(figsize=(8, 6))
bars = plt.bar(df['Argument'], df['Removal-based AAE'], color=colors)

# Adding horizontal lines
plt.axhline(0, color='#E5E5E5', linewidth=1.3, alpha=0.7)

# Adding grid
plt.grid(axis='y', color = '#E5E5E5', linestyle = '--', linewidth = 0.5)

# Setting labels
plt.xlabel('Argument', fontsize='xx-large')
plt.ylabel('Removal-based AAE', fontsize='xx-large')
plt.tick_params(axis='both', which='major', labelsize=16)

# Display the plot
plt.show()

# %%
# Shapley-AAE

data = {
    'Argument': ['s7', 's9', 's10', 's8', 'c1', 's3', 'c2', 's5', 's4', 's0', 's2', 's1', 'c3', 'c0', 'c4', 's6'],
    'Shapley-based AAE': [0.2854, 0.2592, 0.2578, 0.2564, 0.0205, 0.0079, 0.0018, 0.0008, 0.0008, -0.0006, -0.0009, -0.0012, -0.0013, -0.0017, -0.0102, -0.0109]
}

# Creating DataFrame
df = pd.DataFrame(data)

# Plotting the bar chart
colors = ['skyblue' if val >= 0 else 'lightcoral' for val in df['Shapley-based AAE']]
plt.figure(figsize=(8, 6))
bars = plt.bar(df['Argument'], df['Shapley-based AAE'], color=colors)

# Adding horizontal lines
plt.axhline(0, color='#E5E5E5', linewidth=1.3, alpha=0.7)

# Adding grid
plt.grid(axis='y', color = '#E5E5E5', linestyle = '--', linewidth = 0.5)

# Setting labels
plt.xlabel('Argument', fontsize='xx-large')
plt.ylabel('Shapley-based AAE', fontsize='xx-large')
plt.tick_params(axis='both', which='major', labelsize=16)

# Display the plot
plt.show()

# %%
# Removal-RAE

data = {
    'Relation': ['(s7, c5)', '(s8, c5)', '(s9, c5)', '(s10, c5)', '(c5, s7)', '(c5, s8)', '(c5, s9)', '(c5, s10)',
                 '(c5, c4)', '(c1, s7)', '(s7, c1)', '(s3, c1)', '(c2, s3)', '(c1, s3)', '(c1, c0)', '(s3, c2)',
                 '(s4, c2)', '(s5, c2)', '(c3, c2)', '(s6, c3)', '(c3, s6)', '(s6, c4)', '(c4, s6)', '(c4, c5)',
                 '(c2, c3)', '(c2, s4)', '(c2, s5)', '(c0, s0)', '(c0, s1)', '(c0, s2)', '(s0, c0)', '(s1, c0)',
                 '(s2, c0)', '(c0, c1)'],
    'Removal-based RAE': [0.083473613, 0.066745475, 0.066745475, 0.066745475, 0.022507211, 0.014968725, 0.014968725,
                          0.014968725, 0.014703252, 0.006793938, 0.006577898, 0.00657602, 0.002946488, 0.000805779,
                          0.000695966, 0.000212036, 8.51907E-05, 8.51907E-05, -7.91323E-06, -7.91323E-06, -7.91323E-06,
                          -7.91323E-06, -7.91323E-06, -7.91499E-06, -0.000115977, -0.00012035, -0.00012035, -0.00064107,
                          -0.00064107, -0.00064107, -0.002436075, -0.002436075, -0.002436075, -0.002598473]
}

# Creating DataFrame
df = pd.DataFrame(data)

# Plotting the bar chart
colors = ['skyblue' if val >= 0 else 'lightcoral' for val in df['Removal-based RAE']]
plt.figure(figsize=(10, 7.35))
bars = plt.bar(df['Relation'], df['Removal-based RAE'], color=colors)

# Adding horizontal lines
plt.axhline(0, color='#E5E5E5', linewidth=1.3, alpha=0.7)

# Adding grid
plt.grid(axis='y', color = '#E5E5E5', linestyle = '--', linewidth = 0.5)

# Setting labels
plt.xlabel('Relation', fontsize='xx-large')
plt.ylabel('Removal-based RAE', fontsize='xx-large')
plt.tick_params(axis='both', which='major', labelsize=16)

plt.xticks(rotation=90)
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Shapley-RAE

data = {
    "Relation": ["(s7, c5)", "(s10, c5)", "(s8, c5)", "(s9, c5)", "(c5, s7)", "(c5, s9)", "(c5, s10)", "(c5, s8)", "(c5, c4)", "(c1, s7)", "(s3, c1)", "(s7, c1)", "(s3, c2)", "(s4, c2)", "(c2, s3)", "(s5, c2)", "(c2, c3)", "(c1, s3)", "(c1, c0)", "(c2, s5)", "(c2, s4)", "(c0, s2)", "(c0, s1)", "(c0, s0)", "(c3, c2)", "(s2, c0)", "(s0, c0)", "(s1, c0)", "(s6, c3)", "(c3, s6)", "(c4, s6)", "(c0, c1)", "(c4, c5)", "(s6, c4)"],
    "Shapley-based RAE": [0.255513421, 0.247761961, 0.245927825, 0.238930772, 0.024524066, 0.022019375, 0.020724751, 0.020059231, 0.015153831, 0.009541657, 0.006460594, 0.005974419, 0.001282426, 0.001206074, 0.00114098, 0.001083422, 0.000928671, 0.000881815, 0.000834337, 0.000670102, 0.000631869, 0.000586827, 0.000558687, 0.00055825, 0.000164534, 0.000144884, -1.72E-05, -3.68E-05, -0.000276491, -0.000465298, -0.001147533, -0.001659705, -0.028383722, -0.029099303]
}

# Creating DataFrame
df = pd.DataFrame(data)

# Plotting the bar chart
colors = ['skyblue' if val >= 0 else 'lightcoral' for val in df['Shapley-based RAE']]
plt.figure(figsize=(10, 7.35))
bars = plt.bar(df['Relation'], df['Shapley-based RAE'], color=colors)

# Adding horizontal lines
plt.axhline(0, color='#E5E5E5', linewidth=1.3, alpha=0.7)

# Adding grid
plt.grid(axis='y', color = '#E5E5E5', linestyle = '--', linewidth = 0.5)

# Setting labels
plt.xlabel('Relation', fontsize='xx-large')
plt.ylabel('Shapley-based RAE', fontsize='xx-large')
plt.tick_params(axis='both', which='major', labelsize=16)

plt.xticks(rotation=90)
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 数据
data = {
    'Relation': ['(s7, c5)', '(s8, c5)', '(s9, c5)', '(s10, c5)', '(c5, s7)', '(c5, s8)', '(c5, s9)', '(c5, s10)',
                 '(c5, c4)', '(c1, s7)', '(s7, c1)', '(s3, c1)', '(c2, s3)', '(c1, s3)', '(c1, c0)', '(s3, c2)',
                 '(s4, c2)', '(s5, c2)', '(c3, c2)', '(s6, c3)', '(c3, s6)', '(s6, c4)', '(c4, s6)', '(c4, c5)',
                 '(c2, c3)', '(c2, s4)', '(c2, s5)', '(c0, s0)', '(c0, s1)', '(c0, s2)', '(s0, c0)', '(s1, c0)',
                 '(s2, c0)', '(c0, c1)'],
    'Removal-based RAE': [0.083473613, 0.066745475, 0.066745475, 0.066745475, 0.022507211, 0.014968725, 0.014968725,
                          0.014968725, 0.014703252, 0.006793938, 0.006577898, 0.00657602, 0.002946488, 0.000805779,
                          0.000695966, 0.000212036, 8.51907E-05, 8.51907E-05, -7.91323E-06, -7.91323E-06, -7.91323E-06,
                          -7.91323E-06, -7.91323E-06, -7.91499E-06, -0.000115977, -0.00012035, -0.00012035, -0.00064107,
                          -0.00064107, -0.00064107, -0.002436075, -0.002436075, -0.002436075, -0.002598473]
}

df = pd.DataFrame(data)

# 颜色设置
colors = ['skyblue' if x >= 0 else 'lightcoral' for x in df["Removal-based RAE"]]

# 绘制柱状图
plt.figure(figsize=(6, 9))
plt.barh(df["Relation"], df["Removal-based RAE"], color=colors)
plt.xlabel('Removal-based RAE', fontsize='xx-large')
plt.ylabel('Relation', fontsize='xx-large')
plt.tick_params(axis='both', which='major', labelsize=16)

plt.gca().invert_yaxis()
# plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.grid(axis='x', color = '#E5E5E5', linestyle = '--', linewidth = 0.5)
plt.tight_layout()

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 数据
data = {
    "Relation": ["(s7, c5)", "(s10, c5)", "(s8, c5)", "(s9, c5)", "(c5, s7)", "(c5, s9)", "(c5, s10)", "(c5, s8)", "(c5, c4)", "(c1, s7)", "(s3, c1)", "(s7, c1)", "(s3, c2)", "(s4, c2)", "(c2, s3)", "(s5, c2)", "(c2, c3)", "(c1, s3)", "(c1, c0)", "(c2, s5)", "(c2, s4)", "(c0, s2)", "(c0, s1)", "(c0, s0)", "(c3, c2)", "(s2, c0)", "(s0, c0)", "(s1, c0)", "(s6, c3)", "(c3, s6)", "(c4, s6)", "(c0, c1)", "(c4, c5)", "(s6, c4)"],
    "Shapley-based RAE": [0.255513421, 0.247761961, 0.245927825, 0.238930772, 0.024524066, 0.022019375, 0.020724751, 0.020059231, 0.015153831, 0.009541657, 0.006460594, 0.005974419, 0.001282426, 0.001206074, 0.00114098, 0.001083422, 0.000928671, 0.000881815, 0.000834337, 0.000670102, 0.000631869, 0.000586827, 0.000558687, 0.00055825, 0.000164534, 0.000144884, -1.72E-05, -3.68E-05, -0.000276491, -0.000465298, -0.001147533, -0.001659705, -0.028383722, -0.029099303]
}

df = pd.DataFrame(data)

# 颜色设置
colors = ['skyblue' if x >= 0 else 'lightcoral' for x in df["Shapley-based RAE"]]

# 绘制柱状图
plt.figure(figsize=(6, 9))
plt.barh(df["Relation"], df["Shapley-based RAE"], color=colors)
plt.xlabel('Shapley-based RAE', fontsize='xx-large')
plt.ylabel('Relation', fontsize='xx-large')
plt.tick_params(axis='both', which='major', labelsize=16)
# plt.title('Shapley-based RAE by Relation')
plt.gca().invert_yaxis()
# plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.grid(axis='x', color = '#E5E5E5', linestyle = '--', linewidth = 0.5)
plt.tight_layout()

# 显示图形
plt.show()
